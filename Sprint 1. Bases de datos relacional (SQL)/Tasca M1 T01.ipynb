# %% [markdown]
# # Tasca M1 T01

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# *From the attached document (structure and data), create a database with MySQL. Display the main features of the created schema and explains the different tables and variables that exist.*

# %% [markdown]
# Main features of the movies schema:

# %% [markdown]
# ![details.PNG](attachment:details.PNG)

# %% [markdown]
# Tables in the schema movies:

# %% [markdown]
# ![tables.PNG](attachment:tables.PNG)

# %% [markdown]
# Variables in the movies schema:

# %% [markdown]
# ![columns.PNG](attachment:columns.PNG)

# %% [markdown]
# ### Exercise 2

# %% [markdown]
# *Perform the following query on the newly created database:
# You must obtain the name, country and date of birth of those persons for whom a date of death is not recorded and order the data of the oldest person to the youngest person.*

# %% [markdown]
# ![exercise2.PNG](attachment:exercise2.PNG)

# %% [markdown]
# ### Exercise 3

# %% [markdown]
# *Perform the following query on the newly created database: You must obtain the gender name and the total number of films of this genre and sort it in descending order of total number of films.*

# %% [markdown]
# ![exercise3.PNG](attachment:exercise3.PNG)

# %% [markdown]
# ### Exercise 4

# %% [markdown]
# *Perform the following query on the newly created database: You must obtain, for each person, their name and the maximum number of different roles they have had in the same film. Subsequently, show only those people who have assumed more than one role in the same film.*

# %% [markdown]
# ![exercise4.PNG](attachment:exercise4.PNG)

# %% [markdown]
# ### Exercise 5

# %% [markdown]
# *Perform the following operation on the newly created database: You have to create a new genre called "Documental" which has as identifier the number 69.*

# %% [markdown]
# ![exercise5.PNG](attachment:exercise5.PNG)

# %% [markdown]
# ### Exercise 6

# %% [markdown]
# *Perform the following operation on the newly created database: Remove the film "La Gran Familia Española" from the database.*

# %% [markdown]
# ![exercise6.PNG](attachment:exercise6.PNG)

# %% [markdown]
# ### Exercise 7

# %% [markdown]
# *Perform the following operation on the newly created database: change the genre of the film "Ocho apellidos catalanes" to comedy, not romantic.*

# %% [markdown]
# ![exercise7.PNG](attachment:exercise7.PNG)
